# %%
#data from https://www.census.gov/data/datasets/time-series/demo/popest/2020s-counties-total.html

# import pandas lib
import pandas as pd
import matplotlib.pyplot as plt
#get data
data_file = '/Users/chrisv/data_gov/data/co-est2022-alldata.csv'

#read into pandas
data = pd.read_csv(data_file)

#check data loaded, use the describe method so that we can see some genrated stats on the data
data.describe()
# Out:
#             SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3195.000000  3195.000000  3195.000000  3195.000000  3195.000000
# mean     49.840376     2.668545     5.191236    30.243505   102.215962
# std       1.253497     0.808144     1.975916    15.162061   107.495775
# min      40.000000     1.000000     1.000000     1.000000     0.000000
# 25%      50.000000     2.000000     4.000000    18.000000    33.000000
# 50%      50.000000     3.000000     5.000000    29.000000    77.000000
# 75%      50.000000     3.000000     7.000000    45.000000   133.000000
# max      50.000000     4.000000     9.000000    56.000000   840.000000
#
#        ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# count       3.195000e+03     3.195000e+03     3.195000e+03     3.195000e+03
# mean        2.074801e+05     2.075189e+05     2.078445e+05     2.086307e+05
# std         1.269693e+06     1.269732e+06     1.268618e+06     1.273099e+06
# ...

# %%
#SELECT rows where COLOMN IS VALUE


data.loc[data['STNAME'] == 'Alabama']
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0       40       3         6      1       0  Alabama            Alabama
# 1       50       3         6      1       1  Alabama     Autauga County
# 2       50       3         6      1       3  Alabama     Baldwin County
# 3       50       3         6      1       5  Alabama     Barbour County
# 4       50       3         6      1       7  Alabama        Bibb County
# ..     ...     ...       ...    ...     ...      ...                ...
# 63      50       3         6      1     125  Alabama  Tuscaloosa County
# 64      50       3         6      1     127  Alabama      Walker County
# 65      50       3         6      1     129  Alabama  Washington County
# 66      50       3         6      1     131  Alabama      Wilcox County
# 67      50       3         6      1     133  Alabama     Winston County
#
#     ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RDEATH2021  \
# ...

# %%
#filter columns a key word
filter_col = [col for col in data if col.startswith('S')]
data[filter_col]
# Out:
#       SUMLEV  STATE   STNAME
# 0         40      1  Alabama
# 1         50      1  Alabama
# 2         50      1  Alabama
# 3         50      1  Alabama
# 4         50      1  Alabama
# ...      ...    ...      ...
# 3190      50     56  Wyoming
# 3191      50     56  Wyoming
# 3192      50     56  Wyoming
# 3193      50     56  Wyoming
# 3194      50     56  Wyoming
#
# [3195 rows x 3 columns]

# %%
#Filter rows in a specific column that start with 'C'
#loc accesses a group of rows and columns
data.loc[data['CTYNAME'].str.startswith('Cof', na=False)]
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME        CTYNAME  \
# 16        50       3         6      1      31    Alabama  Coffee County
# 433       50       3         5     13      69    Georgia  Coffee County
# 922       50       2         4     20      31     Kansas  Coffey County
# 2488      50       3         6     47      31  Tennessee  Coffee County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RDEATH2021  \
# 16                53460            53547            54171  ...   13.405373
# 433               43088            43052            42997  ...   13.248266
# 922                8358             8356             8343  ...   13.174442
# 2488              57882            58134            58933  ...   15.034126
#
#       RDEATH2022  RNATURALCHG2021  RNATURALCHG2022  RINTERNATIONALMIG2021  \
# 16     12.920276        -0.816948        -0.348701               0.482742
# 433    13.183395        -0.604307        -0.208892               0.464851
# ...

# %%
#data by slicing 
data.iloc[:, 1:4]
# Out:
#       REGION  DIVISION  STATE
# 0          3         6      1
# 1          3         6      1
# 2          3         6      1
# 3          3         6      1
# 4          3         6      1
# ...      ...       ...    ...
# 3190       4         8     56
# 3191       4         8     56
# 3192       4         8     56
# 3193       4         8     56
# 3194       4         8     56
#
# [3195 rows x 3 columns]

# %%
#get counts of each state using value_counts()
data['STNAME'].value_counts()
# Out:
# STNAME
# Texas                   255
# Georgia                 160
# Virginia                134
# Kentucky                121
# Missouri                116
# Kansas                  106
# Illinois                103
# North Carolina          101
# Iowa                    100
# Tennessee                96
# Nebraska                 94
# Indiana                  93
# Ohio                     89
# Minnesota                88
# Michigan                 84
# Mississippi              83
# Oklahoma                 78
# Arkansas                 76
# Wisconsin                73
# Pennsylvania             68
# Alabama                  68
# Florida                  68
# South Dakota             67
# Colorado                 65
# Louisiana                65
# New York                 63
# California               59
# Montana                  57
# West Virginia            56
# North Dakota             54
# South Carolina           47
# Idaho                    45
# Washington               40
# ...

# %%
#basic methods, just an example.
city_count = data.groupby(by='STNAME').CTYNAME.count()
mean = city_count.mean()
median = city_count.median()
std = city_count.std()
print(f"Mean: {mean}, Median: {median}, Standard Deviation: {std}")
# Out:
# Mean: 62.64705882352941, Median: 63.0, Standard Deviation: 46.725934353166984

# %%
#group data by state and est 2020 pop 
grouped_data = data.groupby('STNAME')['POPESTIMATE2020'].sum().reset_index()
grouped_data = grouped_data.sort_values(by='POPESTIMATE2020', ascending=False)
grouped_data
# Out:
#                   STNAME  POPESTIMATE2020
# 4             California         79003306
# 43                 Texas         58464948
# 9                Florida         43179204
# 32              New York         40216592
# 38          Pennsylvania         25988880
# 13              Illinois         25573160
# 35                  Ohio         23595034
# 10               Georgia         21459656
# 33        North Carolina         20898890
# 22              Michigan         20139154
# 30            New Jersey         18543378
# 46              Virginia         17272942
# 47            Washington         15448062
# 2                Arizona         14359886
# 21         Massachusetts         13991458
# 42             Tennessee         13851238
# 14               Indiana         13577598
# 20              Maryland         12346410
# 25              Missouri         12307996
# 49             Wisconsin         11792542
# 5               Colorado         11569730
# ...

# %%
plt.figure(figsize=(12, 8)) 

# bar plot 
plt.bar(grouped_data['STNAME'], grouped_data['POPESTIMATE2020'], color='skyblue')

#rotate x-axis labels for better readability (optional)
plt.xticks(rotation=90)

#add labels and title
plt.xlabel('State')
plt.ylabel('Population Estimate 2020')
plt.title('Population Estimate 2020 per State')

#plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 12)) 
# horizontal bar plot 
plt.barh(grouped_data['STNAME'], grouped_data['POPESTIMATE2020'], color='skyblue')

#rotate x-axis labels for better readability (optional)
plt.xticks(rotation=90)

#add labels and title
plt.xlabel('Population Estimate 2020')
plt.ylabel('State')
plt.title('Population Estimate 2020 per State')

#plot
plt.tight_layout()
plt.show()

# %%
#sum all births per state
grouped_birth_data = data.groupby('STNAME')['BIRTHS2020'].sum().reset_index()
grouped_birth_data = grouped_birth_data.sort_values(by='BIRTHS2020', ascending=False)
grouped_birth_data
# Out:
#                   STNAME  BIRTHS2020
# 4             California      206246
# 43                 Texas      176530
# 32              New York      106166
# 9                Florida      100584
# 13              Illinois       66908
# 38          Pennsylvania       65802
# 35                  Ohio       64682
# 10               Georgia       59684
# 33        North Carolina       57350
# 22              Michigan       53172
# 30            New Jersey       49438
# 46              Virginia       47160
# 47            Washington       42208
# 14               Indiana       38886
# 42             Tennessee       38500
# 2                Arizona       36220
# 25              Missouri       34476
# 20              Maryland       34312
# 21         Massachusetts       34224
# 23             Minnesota       32922
# 5               Colorado       31178
# 49             Wisconsin       31108
# 0                Alabama       27734
# 18             Louisiana       27110
# ...

# %%
#state birth 2020 using column BIRTHS2020

plt.figure(figsize=(10, 12)) 
# horizontal bar plot 
plt.barh(grouped_birth_data['STNAME'], grouped_birth_data['BIRTHS2020'], color='skyblue')

#rotate x-axis labels for better readability (optional)
plt.xticks(rotation=90)

#add labels and title
plt.xlabel('State Births 2020')
plt.ylabel('State')
plt.title('Briths per State in 2020')

#plot
plt.tight_layout()
plt.show()

# %%
#take a look at the columns 
data.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'ESTIMATESBASE2020', 'POPESTIMATE2020', 'POPESTIMATE2021',
#        'POPESTIMATE2022', 'NPOPCHG2020', 'NPOPCHG2021', 'NPOPCHG2022',
#        'BIRTHS2020', 'BIRTHS2021', 'BIRTHS2022', 'DEATHS2020', 'DEATHS2021',
#        'DEATHS2022', 'NATURALCHG2020', 'NATURALCHG2021', 'NATURALCHG2022',
#        'INTERNATIONALMIG2020', 'INTERNATIONALMIG2021', 'INTERNATIONALMIG2022',
#        'DOMESTICMIG2020', 'DOMESTICMIG2021', 'DOMESTICMIG2022', 'NETMIG2020',
#        'NETMIG2021', 'NETMIG2022', 'RESIDUAL2020', 'RESIDUAL2021',
#        'RESIDUAL2022', 'GQESTIMATESBASE2020', 'GQESTIMATES2020',
#        'GQESTIMATES2021', 'GQESTIMATES2022', 'RBIRTH2021', 'RBIRTH2022',
#        'RDEATH2021', 'RDEATH2022', 'RNATURALCHG2021', 'RNATURALCHG2022',
#        'RINTERNATIONALMIG2021', 'RINTERNATIONALMIG2022', 'RDOMESTICMIG2021',
#        'RDOMESTICMIG2022', 'RNETMIG2021', 'RNETMIG2022'],
#       dtype='object')

# %%
#update column names to something more readable
new_col_names = {
    'SUMLEV': 'Summary Level',
    'REGION': 'Region',
    'DIVISION': 'Division',
    'STATE': 'State Code',
    'COUNTY': 'County Code',
    'STNAME': 'State Name',
    'CTYNAME': 'County Name',
    'ESTIMATESBASE2020': 'Estimates Base for 2020',
    'POPESTIMATE2020': 'Population Estimate for 2020',
    'POPESTIMATE2021': 'Population Estimate for 2021',
    'POPESTIMATE2022': 'Population Estimate for 2022',
    'NPOPCHG2020': 'Population Change for 2020',
    'NPOPCHG2021': 'Population Change for 2021',
    'NPOPCHG2022': 'Population Change for 2022',
    'BIRTHS2020': 'Births in 2020',
    'BIRTHS2021': 'Births in 2021',
    'BIRTHS2022': 'Births in 2022',
    'DEATHS2020': 'Deaths in 2020',
    'DEATHS2021': 'Deaths in 2021',
    'DEATHS2022': 'Deaths in 2022',
    'NATURALCHG2020': 'Natural Change in 2020',
    'NATURALCHG2021': 'Natural Change in 2021',
    'NATURALCHG2022': 'Natural Change in 2022',
    'INTERNATIONALMIG2020': 'International Migration in 2020',
    'INTERNATIONALMIG2021': 'International Migration in 2021',
    'INTERNATIONALMIG2022': 'International Migration in 2022',
    'DOMESTICMIG2020': 'Domestic Migration in 2020',
    'DOMESTICMIG2021': 'Domestic Migration in 2021',
    'DOMESTICMIG2022': 'Domestic Migration in 2022',
    'NETMIG2020': 'Net Migration in 2020',
    'NETMIG2021': 'Net Migration in 2021',
    'NETMIG2022': 'Net Migration in 2022',
    'RESIDUAL2020': 'Residual for 2020',
    'RESIDUAL2021': 'Residual for 2021',
    'RESIDUAL2022': 'Residual for 2022',
    'GQESTIMATESBASE2020': 'Group Quarters Estimates Base for 2020',
    'GQESTIMATES2020': 'Group Quarters Estimates for 2020',
    'GQESTIMATES2021': 'Group Quarters Estimates for 2021',
    'GQESTIMATES2022': 'Group Quarters Estimates for 2022',
    'RBIRTH2021': 'Birth Rate in 2021',
    'RBIRTH2022': 'Birth Rate in 2022',
    'RDEATH2021': 'Death Rate in 2021',
    'RDEATH2022': 'Death Rate in 2022',
    'RNATURALCHG2021': 'Natural Change Rate in 2021',
    'RNATURALCHG2022': 'Natural Change Rate in 2022',
    'RINTERNATIONALMIG2021': 'International Migration Rate in 2021',
    'RINTERNATIONALMIG2022': 'International Migration Rate in 2022',
    'RDOMESTICMIG2021': 'Domestic Migration Rate in 2021',
    'RDOMESTICMIG2022': 'Domestic Migration Rate in 2022',
    'RNETMIG2021': 'Net Migration Rate in 2021',
    'RNETMIG2022': 'Net Migration Rate in 2022'
}


data.rename(new_col_names , axis=1, inplace=True)
#check if names are changed
data
# Out:
#       Summary Level  Region  Division  State Code  County Code State Name  \
# 0                40       3         6           1            0    Alabama
# 1                50       3         6           1            1    Alabama
# 2                50       3         6           1            3    Alabama
# 3                50       3         6           1            5    Alabama
# 4                50       3         6           1            7    Alabama
# ...             ...     ...       ...         ...          ...        ...
# 3190             50       4         8          56           37    Wyoming
# 3191             50       4         8          56           39    Wyoming
# 3192             50       4         8          56           41    Wyoming
# 3193             50       4         8          56           43    Wyoming
# 3194             50       4         8          56           45    Wyoming
#
#             County Name  Estimates Base for 2020  \
# ...
