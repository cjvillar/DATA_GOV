# %%
# import pandas lib
import pandas as pd

#get data
data_file = '/Users/chrisv/data_gov/data/PD_Incident_Reports_2018_to_Present_100_rows.csv'

#read into pandas
data = pd.read_csv(data_file)

# %%
#check data loaded
data.info()

# %%
#look at row and column numbers (row,columns)
data.shape
# Out:
# (99, 35)

# %%
#view as table
data
# Out:
#          Incident Datetime Incident Date Incident Time  Incident Year  \
# 0   2023/03/13 11:41:00 PM    2023/03/13         23:41           2023
# 1   2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2   2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3   2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4   2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
# ..                     ...           ...           ...            ...
# 94  2022/03/23 07:00:00 PM    2022/03/23         19:00           2022
# 95  2019/08/15 02:00:00 PM    2019/08/15         14:00           2019
# 96  2020/02/18 03:31:00 PM    2020/02/18         15:31           2020
# 97  2019/01/10 03:00:00 PM    2019/01/10         15:00           2019
# 98  2018/08/03 10:00:00 PM    2018/08/03         22:00           2018
#
#    Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0                Monday  2023/03/13 11:41:00 PM  125373607041      1253736
# 1             Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 2                Monday  2023/03/13 01:17:00 PM  125357107041      1253571
# 3                Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 4               Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
# ..                  ...                     ...           ...          ...
# 94            Wednesday  2022/03/27 12:20:00 PM  113601306372      1136013
# 95             Thursday  2019/09/17 11:05:00 AM   84829571000       848295
# 96              Tuesday  2020/02/18 05:24:00 PM   90473571000       904735
# 97             Thursday  2019/03/06 05:54:00 PM   77921671000       779216
# 98               Friday  2018/08/06 12:40:00 PM   70032071000       700320
#
#     Incident Number  CAD Number  ... Longitude Point Neighborhoods  \
# 0         230167874         NaN  ...       NaN   NaN           NaN
# 1         236046151         NaN  ...       NaN   NaN           NaN
# 2         220343896         NaN  ...       NaN   NaN           NaN
# 3         230174885         NaN  ...       NaN   NaN           NaN
# 4         230176728         NaN  ...       NaN   NaN           NaN
# ..              ...         ...  ...       ...   ...           ...
# 94        226050087         NaN  ...       NaN   NaN           NaN
# 95        196195624         NaN  ...       NaN   NaN           NaN
# 96        206038398         NaN  ...       NaN   NaN           NaN
# 97        196050802         NaN  ...       NaN   NaN           NaN
# 98        186179519         NaN  ...       NaN   NaN           NaN
#
#     ESNCAG - Boundary File  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 94                     NaN
# 95                     NaN
# 96                     NaN
# 97                     NaN
# 98                     NaN
#
#    Central Market/Tenderloin Boundary Polygon - Updated  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
#
#    Civic Center Harm Reduction Project Boundary HSOC Zones as of 2018-06-05  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           NaN                         NaN
# ..                                          ...                         ...
# 94                                          NaN                         NaN
# 95                                          NaN                         NaN
# 96                                          NaN                         NaN
# 97                                          NaN                         NaN
# 98                                          NaN                         NaN
#
#    Invest In Neighborhoods (IIN) Areas Current Supervisor Districts  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
# ..                                 ...                          ...
# 94                                 NaN                          NaN
# 95                                 NaN                          NaN
# 96                                 NaN                          NaN
# 97                                 NaN                          NaN
# 98                                 NaN                          NaN
#
#     Current Police Districts
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 94                       NaN
# 95                       NaN
# 96                       NaN
# 97                       NaN
# 98                       NaN
#
# [99 rows x 35 columns]

# %%
#count unique values in a column
data["Incident Year"].value_counts()
# Out:
# Incident Year
# 2023    35
# 2018    16
# 2021    15
# 2022    12
# 2019    12
# 2020     9
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Incident Datetime', 'Incident Date', 'Incident Time', 'Incident Year',
#        'Incident Day of Week', 'Report Datetime', 'Row ID', 'Incident ID',
#        'Incident Number', 'CAD Number', 'Report Type Code',
#        'Report Type Description', 'Filed Online', 'Incident Code',
#        'Incident Category', 'Incident Subcategory', 'Incident Description',
#        'Resolution', 'Intersection', 'CNN', 'Police District',
#        'Analysis Neighborhood', 'Supervisor District',
#        'Supervisor District 2012', 'Latitude', 'Longitude', 'Point',
#        'Neighborhoods', 'ESNCAG - Boundary File',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Civic Center Harm Reduction Project Boundary',
#        'HSOC Zones as of 2018-06-05', 'Invest In Neighborhoods (IIN) Areas',
#        'Current Supervisor Districts', 'Current Police Districts'],
#       dtype='object')

# %%
data["Incident Category"].value_counts()
# Out:
# Incident Category
# Larceny Theft         31
# Lost Property         31
# Recovered Vehicle     17
# Assault                5
# Non-Criminal           5
# Warrant                5
# Drug Violation         1
# Malicious Mischief     1
# Drug Offense           1
# Fraud                  1
# Other Offenses         1
# Name: count, dtype: int64

# %%
#Example of how to use a dict to change columns names for columns 

col_dict = {
    'Incident Date' : 'date',
    'Incident Time' : 'time',
    'Incident Year' : 'year',
    'Incident Category' : 'Crime',    
}

data.rename(col_dict, axis=1, inplace=True)
#check if names are changed
data
# Out:
#          Incident Datetime        date   time  year Incident Day of Week  \
# 0   2023/03/13 11:41:00 PM  2023/03/13  23:41  2023               Monday
# 1   2023/03/01 05:02:00 AM  2023/03/01  05:02  2023            Wednesday
# 2   2023/03/13 01:16:00 PM  2023/03/13  13:16  2023               Monday
# 3   2023/03/13 10:59:00 AM  2023/03/13  10:59  2023               Monday
# 4   2023/03/14 06:44:00 PM  2023/03/14  18:44  2023              Tuesday
# ..                     ...         ...    ...   ...                  ...
# 94  2022/03/23 07:00:00 PM  2022/03/23  19:00  2022            Wednesday
# 95  2019/08/15 02:00:00 PM  2019/08/15  14:00  2019             Thursday
# 96  2020/02/18 03:31:00 PM  2020/02/18  15:31  2020              Tuesday
# 97  2019/01/10 03:00:00 PM  2019/01/10  15:00  2019             Thursday
# 98  2018/08/03 10:00:00 PM  2018/08/03  22:00  2018               Friday
#
#            Report Datetime        Row ID  Incident ID  Incident Number  \
# 0   2023/03/13 11:41:00 PM  125373607041      1253736        230167874
# 1   2023/03/11 03:40:00 PM  125379506374      1253795        236046151
# 2   2023/03/13 01:17:00 PM  125357107041      1253571        220343896
# 3   2023/03/13 11:00:00 AM  125355107041      1253551        230174885
# 4   2023/03/14 06:45:00 PM  125402407041      1254024        230176728
# ..                     ...           ...          ...              ...
# 94  2022/03/27 12:20:00 PM  113601306372      1136013        226050087
# 95  2019/09/17 11:05:00 AM   84829571000       848295        196195624
# 96  2020/02/18 05:24:00 PM   90473571000       904735        206038398
# 97  2019/03/06 05:54:00 PM   77921671000       779216        196050802
# 98  2018/08/06 12:40:00 PM   70032071000       700320        186179519
#
#     CAD Number  ... Longitude Point Neighborhoods  ESNCAG - Boundary File  \
# 0          NaN  ...       NaN   NaN           NaN                     NaN
# 1          NaN  ...       NaN   NaN           NaN                     NaN
# 2          NaN  ...       NaN   NaN           NaN                     NaN
# 3          NaN  ...       NaN   NaN           NaN                     NaN
# 4          NaN  ...       NaN   NaN           NaN                     NaN
# ..         ...  ...       ...   ...           ...                     ...
# 94         NaN  ...       NaN   NaN           NaN                     NaN
# 95         NaN  ...       NaN   NaN           NaN                     NaN
# 96         NaN  ...       NaN   NaN           NaN                     NaN
# 97         NaN  ...       NaN   NaN           NaN                     NaN
# 98         NaN  ...       NaN   NaN           NaN                     NaN
#
#    Central Market/Tenderloin Boundary Polygon - Updated  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
#
#    Civic Center Harm Reduction Project Boundary HSOC Zones as of 2018-06-05  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           NaN                         NaN
# ..                                          ...                         ...
# 94                                          NaN                         NaN
# 95                                          NaN                         NaN
# 96                                          NaN                         NaN
# 97                                          NaN                         NaN
# 98                                          NaN                         NaN
#
#    Invest In Neighborhoods (IIN) Areas Current Supervisor Districts  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
# ..                                 ...                          ...
# 94                                 NaN                          NaN
# 95                                 NaN                          NaN
# 96                                 NaN                          NaN
# 97                                 NaN                          NaN
# 98                                 NaN                          NaN
#
#     Current Police Districts
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 94                       NaN
# 95                       NaN
# 96                       NaN
# 97                       NaN
# 98                       NaN
#
# [99 rows x 35 columns]

# %%
#export to another file format like json
data.to_json('police_data.json',orient="index", indent=2)
